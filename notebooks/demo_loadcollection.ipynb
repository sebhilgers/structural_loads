# %%
from structural_loads.domain import actions, loadcase, loadcollection

# %%
g = loadcase.G

# %%
lc_snow = loadcase.S
lc_g = loadcase.G 
l1 = loadcollection.LoadCollection(name="Demo loads")

# %%
l1.add_area_load("Last 1", lc_snow, 1.0)
l1.add_line_load("Last 2", lc_snow, 2.0)
l1.add_point_load("Last 3", lc_g, 3.0)
# Out:
# PointLoad(name='Last 3', loadcase='Ständige Last', value=3.0, unit='kN')

# %%
l1.to_df()
# Out:
#         type    name  loadcase_name loadcase_category loadcase_description  \
# 0   AreaLoad  Last 1         Schnee        Schneelast         Schneelasten
# 1   LineLoad  Last 2         Schnee        Schneelast         Schneelasten
# 2  PointLoad  Last 3  Ständige Last     Ständige Last      Ständige Lasten
#
#     action_type action_description  value   unit
# 0  Veränderlich                       1.0  kN/m²
# 1  Veränderlich                       2.0   kN/m
# 2       Ständig                       3.0     kN

# %%
l1
# Out:
# LoadCollection(name='Demo loads', load_count=3)

# %%
l1.
