# %%
from structural_loads.domain import actions, loadcase, loadcollection
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from structural_loads.domain import actions, loadcase, loadcollection
#
# File D:\pycode\structural_loads\src\structural_loads\domain\__init__.py:1
# ----> 1 from structural_loads.domain.loadcollection import LoadCollection
#       3 __all__ = ["LoadCollection"]
#
# File D:\pycode\structural_loads\src\structural_loads\domain\loadcollection.py:6
#       3 from collections.abc import Iterable, Iterator
#       5 from structural_loads.domain.actions import ActionType
# ----> 6 from structural_loads.domain.loadcase import LoadCase
#       7 from structural_loads.domain.loads import AreaLoad, LineLoad, Load, PointLoad
#       9 _ACTION_TYPE_ORDER = {
#      10     ActionType.PERMANENT: 0,
#      11     ActionType.VARIABLE: 1,
#      12     ActionType.ACCIDENTAL: 2,
#      13 }
#
# File D:\pycode\structural_loads\src\structural_loads\domain\loadcase.py:70
#      68 Q_B = LoadCase(name="Nutzlast Kategorie B", category=ActionCategory.OFFICE, description="Büro")
#      69 Q_C = LoadCase(name="Nutzlast Kategorie C", category=ActionCategory.COMMERCIAL, description="Gewerbe")
# ---> 70 Q_D = LoadCase(name="Nutzlast Kategorie D", category=ActionCategory.SHOPPING, description="Verkaufsflächen")
#      71 Q_E = LoadCase(name="Nutzlast Kategorie E", category=ActionCategory.LAGER, description="Lager- und Werkstattflächen")
#      72 W = LoadCase(name="Wind", category=ActionCategory.WIND, description="Windlasten")
#
# AttributeError: type object 'ActionCategory' has no attribute 'SHOPPING'

# %%
g = loadcase.G

# %%
lc_snow = loadcase.S
lc_g = loadcase.G 
l1 = loadcollection.LoadCollection(name="Demo loads")

# %%
l1.add_area_load("Last 1", lc_snow, 1.0)
l1.add_line_load("Last 2", lc_snow, 2.0)
l1.add_point_load("Last 3", lc_g, 3.0)

# %%
l1.to_df()

# %%
l1
