# %%
from structural_loads.domain import actions, loadcase

# %%
einwirkung = actions.ActionDefinition(actions.ActionCategory.ANPRALL)

# %%
einwirkung
# Out:
# ActionDefinition(category=<ActionCategory.ANPRALL: 'Anpralllast'>, type=<ActionType.ACCIDENTAL: 'Aussergewöhnlich'>, factors=ActionFactors(psi_0=1.0, psi_1=1.0, psi_2=1.0, duration_class=<DurationClass.VERY_SHORT: 'very_short'>), description='')

# %%
einwirkung.to_dict()
# Out:
# {'category': 'Anpralllast',
#  'type': 'Aussergewöhnlich',
#  'description': '',
#  'factors': {'psi_0': 1.0,
#   'psi_1': 1.0,
#   'psi_2': 1.0,
#   'duration_class': 'very_short'}}

# %%
einwirkung.to_df()
# Out:
#       category              type description  psi_0  psi_1  psi_2  \
# 0  Anpralllast  Aussergewöhnlich                1.0    1.0    1.0
#
#   duration_class
# 0     very_short

# %%
lc1 = loadcase.LoadCase("LC1", actions.ActionCategory.ROOF)

# %%
lc1.to_dict()
# Out:
# {'name': 'LC1', 'category': 'Kat. H: Dächer', 'description': None}

# %%
lc1.to_df()
# Out:
#   name        category description
# 0  LC1  Kat. H: Dächer        None
