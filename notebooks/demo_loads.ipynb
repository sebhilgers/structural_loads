# %%
from structural_loads.domain import actions, loadcase, loads

# %%
ein1 = loadcase.LoadCase("LC1", actions.ActionCategory.PERMANENT)

# %%
fl1 = loads.AreaLoad("FL1", ein1, 15)
fl1
# Out:
# AreaLoad(name='FL1', loadcase='LC1', value=15.0, unit='kN/m²')

# %%
fl1.to_dict()
# Out:
# {'type': 'AreaLoad',
#  'name': 'FL1',
#  'loadcase': {'name': 'LC1', 'category': 'Ständige Last', 'description': None},
#  'value': 15.0,
#  'unit': 'kN/m²'}

# %%
fl1.to_df()
# Out:
#        type name loadcase_name loadcase_category loadcase_description  value  \
# 0  AreaLoad  FL1           LC1     Ständige Last                 None   15.0
#
#     unit
# 0  kN/m²
