# %%
from structural_loads.domain import loadcase, loads, actions, tributaryarea

# %%
a1 = tributaryarea.TributaryArea("A1", 10, 10, 1.1, 1.)
a2 = tributaryarea.TributaryArea("A2", 10, 10)

# %%
a1.to_dict()
# Out:
# {'name': 'A1',
#  'distribution_type': 'two_way_area',
#  'tributary_width_x': 10.0,
#  'tributary_width_y': 10.0,
#  'factor_x': 1.1,
#  'factor_y': 1.0,
#  'reference_strip_length': None,
#  'effective_tributary_width_x': 11.0,
#  'effective_tributary_width_y': 10.0,
#  'effective_area': 110.0}

# %%
a1.to_df()
# Out:
#   name distribution_type  tributary_width_x  tributary_width_y  factor_x  \
# 0   A1      two_way_area               10.0               10.0       1.1
#
#    factor_y reference_strip_length  effective_tributary_width_x  \
# 0       1.0                   None                         11.0
#
#    effective_tributary_width_y  effective_area
# 0                         10.0           110.0
